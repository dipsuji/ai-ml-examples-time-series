# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import sklearn.preprocessing
from sklearn.metrics import r2_score

from keras.layers import Dense,Dropout,SimpleRNN,LSTM
from keras.models import Sequential

import timeit
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21584/3641418894.py in <module>
#       7 from sklearn.metrics import r2_score
#       8
# ----> 9 from keras.layers import Dense,Dropout,SimpleRNN,LSTM
#      10 from keras.models import Sequential
#      11
#
# c:\users\maury\appdata\local\programs\python\python39\lib\site-packages\keras\__init__.py in <module>
#      23
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from keras import models
#      26
#      27 from keras.engine.input_layer import Input
#
# c:\users\maury\appdata\local\programs\python\python39\lib\site-packages\keras\models.py in <module>
#      17
#      18 import tensorflow.compat.v2 as tf
# ---> 19 from keras import backend
#      20 from keras import metrics as metrics_module
#      21 from keras import optimizer_v1
#
# ...

# %%
data_size = 5000 # 116189
train_size = 3000 # set if total data size 5000 
# data_size = 116189
# train_size = 110000 # set if total data size approx 140000
epoch = 10

# %%
df_pv = pd.read_csv('pv_generation.csv', parse_dates=['datetime'], ) # powerConsumption
df_pv
# Out:
#       Unnamed: 0            datetime  powerGeneration resourceId deviceId
# 0              0 2020-01-01 00:00:00              0.0        R_1    pvR_1
# 1              1 2020-01-01 00:30:00              0.0        R_1    pvR_1
# 2              2 2020-01-01 01:00:00              0.0        R_1    pvR_1
# 3              3 2020-01-01 01:30:00              0.0        R_1    pvR_1
# 4              4 2020-01-01 02:00:00              0.0        R_1    pvR_1
# ...          ...                 ...              ...        ...      ...
# 4267        4267 2020-03-29 21:30:00              0.0        R_1    pvR_1
# 4268        4268 2020-03-29 22:00:00              0.0        R_1    pvR_1
# 4269        4269 2020-03-29 22:30:00              0.0        R_1    pvR_1
# 4270        4270 2020-03-29 23:00:00              0.0        R_1    pvR_1
# 4271        4271 2020-03-29 23:30:00              0.0        R_1    pvR_1
#
# [4272 rows x 5 columns]

# %% [markdown]
# # New section - Data preprocess

# %%
df_pv = pd.read_csv('pv_generation.csv', parse_dates=['dateTime']) # powerConsumption
df_weather = pd.read_csv('history_weather_data.csv', parse_dates=['dateTime']) # powerConsumption
df_pv.head()
# Out:
#                    dateTime resourceId deviceId  powerGeneration
# 0 2021-02-21 15:00:00+09:00        R_1    pvR_1            142.0
# 1 2021-02-21 15:30:00+09:00        R_1    pvR_1            143.0
# 2 2021-02-21 16:00:00+09:00        R_1    pvR_1            143.0
# 3 2021-02-21 16:30:00+09:00        R_1    pvR_1            143.0
# 4 2021-02-21 17:00:00+09:00        R_1    pvR_1            135.0

# %%
df_weather.head()
# Out:
#                    dateTime     temp  ...  wind_speed  weather_main
# 0 2021-02-21 13:00:00+09:00  270.475  ...           1         clear
# 1 2021-02-21 13:30:00+09:00  270.475  ...           1         clear
# 2 2021-02-21 14:00:00+09:00  269.686  ...           0         clear
# 3 2021-02-21 14:30:00+09:00  269.686  ...           0         clear
# 4 2021-02-21 15:00:00+09:00  269.686  ...           0         clear
#
# [5 rows x 6 columns]

# %%
df_pv = pd.read_csv('pv_generation.csv', index_col='dateTime', parse_dates=['dateTime']) # powerConsumption

# %%
df_pv = df_pv[df_pv.resourceId == "R_1"]
df_pv
# Out:
#                           resourceId deviceId  powerGeneration
# dateTime
# 2021-02-21 15:00:00+09:00        R_1    pvR_1            142.0
# 2021-02-21 15:30:00+09:00        R_1    pvR_1            143.0
# 2021-02-21 16:00:00+09:00        R_1    pvR_1            143.0
# 2021-02-21 16:30:00+09:00        R_1    pvR_1            143.0
# 2021-02-21 17:00:00+09:00        R_1    pvR_1            135.0
# ...                              ...      ...              ...
# 2021-05-21 13:00:00+09:00        R_1    pvR_1           1243.0
# 2021-05-21 13:30:00+09:00        R_1    pvR_1            892.0
# 2021-05-21 14:00:00+09:00        R_1    pvR_1            856.0
# 2021-05-21 14:30:00+09:00        R_1    pvR_1            853.0
# 2021-05-21 15:00:00+09:00        R_1    pvR_1            845.0
#
# [4273 rows x 3 columns]

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %%
plt.figure(figsize=(20,6))
plot_series(df_pv.index, df_pv['powerGeneration'])
plt.show()

# %%
df = df_pv
del df["deviceId"]
del df["resourceId"]
df.isnull().sum().sum()
# Out:
# 14

# %%
df = (df.ffill()+df.bfill())/2
df.isnull().sum().sum()
# Out:
# 0

# %%
scaler = sklearn.preprocessing.MinMaxScaler()
def normalize_data(df):
    df['powerGeneration']=scaler.fit_transform(df['powerGeneration'].values.reshape(-1,1))
    return df

df_norm = normalize_data(df)
df_norm.shape
# Out:
# (4273, 1)

# %%
def load_data(stock, seq_len):
    X_train = []
    y_train = []
    for i in range(seq_len, len(stock)):
        X_train.append(stock.iloc[i-seq_len : i, 0])
        y_train.append(stock.iloc[i, 0])
    
    #1 last 6189 days are going to be used in test
    X_test = X_train[train_size:]             
    y_test = y_train[train_size:]
    
    #2 first 110000 days are going to be used in training
    X_train = X_train[:train_size]           
    y_train = y_train[:train_size]
    
    #3 convert to numpy array
    X_train = np.array(X_train)
    y_train = np.array(y_train)
    
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    
    #4 reshape data to input into RNN models
    X_train = np.reshape(X_train, (train_size, seq_len, 1))
    
    X_test = np.reshape(X_test, (X_test.shape[0], seq_len, 1))
    
    return [X_train, y_train, X_test, y_test]

# %%
seq_len = 10 #choose sequence length

X_train, y_train, X_test, y_test = load_data(df, seq_len)

print('X_train.shape = ',X_train.shape)
print('y_train.shape = ', y_train.shape)
print('X_test.shape = ', X_test.shape)
print('y_test.shape = ',y_test.shape)
# Out:
# X_train.shape =  (3000, 10, 1)
# y_train.shape =  (3000,)
# X_test.shape =  (1263, 10, 1)
# y_test.shape =  (1263,)

# %%
df
# Out:
# 14

# %% [markdown]
# # New section - LSTM Model

# %%
lstm_model = Sequential()
# input shape = (time steps, 1) here we are using 10 time steps
lstm_model.add(LSTM(40,activation="tanh",return_sequences=True, input_shape=(X_train.shape[1],1)))
lstm_model.add(Dropout(0.15))

lstm_model.add(LSTM(40,activation="tanh",return_sequences=True))
lstm_model.add(Dropout(0.15))

lstm_model.add(LSTM(40,activation="tanh",return_sequences=False))
lstm_model.add(Dropout(0.15))

lstm_model.add(Dense(1))

lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 10, 40)            6720
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 40)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 40)            12960
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 40)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 40)                12960
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 40)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 41
# ...

# %%
lstm_model.compile(optimizer="adam",loss="MSE", metrics=['mean_squared_error'])

history =lstm_model.fit(X_train, y_train, epochs=20, batch_size=100)
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['mean_squared_error'], label='test')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 30/30 [==============================] - 4s 17ms/step - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 2/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 3/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 4/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 5/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 6/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 7/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 8/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 9/20
# ...

# %%
start_training_time = timeit.default_timer()
lstm_model.compile(optimizer="adam",loss="MSE", metrics=['mean_squared_error'])
lstm_model.fit(X_train, y_train, epochs=20, batch_size=100)
stop_training_time = round((timeit.default_timer() - start_training_time))
print('Training Time: ', stop_training_time)
# Out:
# Epoch 1/20
# 30/30 [==============================] - 4s 19ms/step - loss: 0.0968 - mean_squared_error: 0.0968
# Epoch 2/20
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0634 - mean_squared_error: 0.0634
# Epoch 3/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0387 - mean_squared_error: 0.0387
# Epoch 4/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0316 - mean_squared_error: 0.0316
# Epoch 5/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0241 - mean_squared_error: 0.0241
# Epoch 6/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0193 - mean_squared_error: 0.0193
# Epoch 7/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0164 - mean_squared_error: 0.0164
# Epoch 8/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0138 - mean_squared_error: 0.0138
# Epoch 9/20
# ...

# %%
trainScore = lstm_model.evaluate(X_train, y_train, verbose=0)
print('Train loss:', trainScore[0])
print('Train accuracy:', trainScore[1])
# Out:
# Train loss: 0.0011904399143531919
# Train accuracy: 0.0011904399143531919

# %%
testScore = lstm_model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', testScore[0]) 
print('Test accuracy:', testScore[1])
# Out:
# Test loss: 0.0014353274600580335
# Test accuracy: 0.0014353274600580335

# %%
lstm_predictions = lstm_model.predict(X_test)

lstm_score = r2_score(y_test, lstm_predictions)
print("R^2 Score of LSTM model = ",lstm_score)
# Out:
# R^2 Score of LSTM model =  0.9865763689885205

# %%
def plot_predictions(test, predicted, title):
    plt.figure(figsize=(16,4))
    plt.plot(test, color='blue',label='Actual power consumption data')
    plt.plot(predicted, alpha=0.7, color='green',label='Predicted power consumption data')
    plt.title(title)
    plt.xlabel('Time')
    plt.ylabel('Normalized power consumption scale')
    plt.legend()
    plt.show()

# %%
plot_predictions(y_test, lstm_predictions, "Predictions made by LSTM model")

# %% [markdown]
# # New section - RNN Model

# %%
# Build Simple RNN 
rnn_model = Sequential()

rnn_model.add(SimpleRNN(40,activation="tanh",return_sequences=True, input_shape=(X_train.shape[1],1)))
rnn_model.add(Dropout(0.15))

rnn_model.add(SimpleRNN(40,activation="tanh",return_sequences=True))
rnn_model.add(Dropout(0.15))

rnn_model.add(SimpleRNN(40,activation="tanh",return_sequences=False))
rnn_model.add(Dropout(0.15))

rnn_model.add(Dense(1))

rnn_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# simple_rnn_3 (SimpleRNN)     (None, 10, 40)            1680
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 10, 40)            0
# _________________________________________________________________
# simple_rnn_4 (SimpleRNN)     (None, 10, 40)            3240
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 10, 40)            0
# _________________________________________________________________
# simple_rnn_5 (SimpleRNN)     (None, 40)                3240
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 40)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 41
# ...

# %%
start_training_time = timeit.default_timer()
rnn_model.compile(optimizer="adam",loss="MSE", metrics=['mean_squared_error'])
rnn_model.fit(X_train, y_train, epochs=epoch, batch_size=1000)
stop_training_time = round((timeit.default_timer() - start_training_time))
print('Training Time: ', stop_training_time)
# Out:
# Epoch 1/10
# 4/4 [==============================] - 2s 41ms/step - loss: 0.6211 - mean_squared_error: 0.6211
# Epoch 2/10
# 4/4 [==============================] - 0s 42ms/step - loss: 0.3830 - mean_squared_error: 0.3830
# Epoch 3/10
# 4/4 [==============================] - 0s 47ms/step - loss: 0.2946 - mean_squared_error: 0.2946
# Epoch 4/10
# 4/4 [==============================] - 0s 44ms/step - loss: 0.2181 - mean_squared_error: 0.2181
# Epoch 5/10
# 4/4 [==============================] - 0s 45ms/step - loss: 0.1768 - mean_squared_error: 0.1768
# Epoch 6/10
# 4/4 [==============================] - 0s 44ms/step - loss: 0.1599 - mean_squared_error: 0.1599
# Epoch 7/10
# 4/4 [==============================] - 0s 52ms/step - loss: 0.1379 - mean_squared_error: 0.1379
# Epoch 8/10
# 4/4 [==============================] - 0s 46ms/step - loss: 0.1199 - mean_squared_error: 0.1199
# Epoch 9/10
# 4/4 [==============================] - 0s 45ms/step - loss: 0.1106 - mean_squared_error: 0.1106
# ...

# %%
rnn_predictions = rnn_model.predict(X_test)

rnn_score = r2_score(y_test,rnn_predictions)
print("R2 Score of RNN model = ",rnn_score)
# Out:
# R2 Score of RNN model =  0.2670265705913847

# %%
rnntrainScore = rnn_model.evaluate(X_train, y_train, verbose=0)
print('Train loss:', rnntrainScore[0]) 
print('Train accuracy:', rnntrainScore[1])
# Out:
# Train loss: 0.00952949933707714
# Train accuracy: 0.00952949933707714

# %%
rnntestScore = rnn_model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', rnntestScore[0]) 
print('Test accuracy:', rnntestScore[1])
# Out:
# Test loss: 0.01567026413977146
# Test accuracy: 0.01567026413977146

# %%
plot_predictions(y_test, rnn_predictions, "Predictions made by simple RNN model")

# %% [markdown]
# # New section - CNN model

# %%
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.layers import Dense, LSTM, RepeatVector, TimeDistributed, Flatten
model_cnn = Sequential()
model_cnn.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])))
model_cnn.add(MaxPooling1D(pool_size=2))
model_cnn.add(Flatten())
model_cnn.add(Dense(50, activation='relu'))
model_cnn.add(Dense(1))
model_cnn.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d_1 (Conv1D)            (None, 9, 64)             192
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 4, 64)             0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 50)                12850
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 51
# ...
# Total params: 13,093
# Trainable params: 13,093
# Non-trainable params: 0
# _________________________________________________________________

# %%
start_training_time = timeit.default_timer()
model_cnn.compile(loss='mse', optimizer="adam", metrics=["mean_squared_error"])
model_cnn.fit(X_train, y_train, validation_data=(X_test, y_test) ,epochs=epoch, verbose=2, batch_size=1000)
stop_training_time = round((timeit.default_timer() - start_training_time))
print('Training Time: ', stop_training_time)
# Out:
# Epoch 1/10
# 4/4 - 1s - loss: 0.1790 - mean_squared_error: 0.1790 - val_loss: 0.0899 - val_mean_squared_error: 0.0899
# Epoch 2/10
# 4/4 - 0s - loss: 0.0794 - mean_squared_error: 0.0794 - val_loss: 0.0349 - val_mean_squared_error: 0.0349
# Epoch 3/10
# 4/4 - 0s - loss: 0.0467 - mean_squared_error: 0.0467 - val_loss: 0.0359 - val_mean_squared_error: 0.0359
# Epoch 4/10
# 4/4 - 0s - loss: 0.0551 - mean_squared_error: 0.0551 - val_loss: 0.0393 - val_mean_squared_error: 0.0393
# Epoch 5/10
# 4/4 - 0s - loss: 0.0522 - mean_squared_error: 0.0522 - val_loss: 0.0304 - val_mean_squared_error: 0.0304
# Epoch 6/10
# 4/4 - 0s - loss: 0.0426 - mean_squared_error: 0.0426 - val_loss: 0.0254 - val_mean_squared_error: 0.0254
# Epoch 7/10
# 4/4 - 0s - loss: 0.0381 - mean_squared_error: 0.0381 - val_loss: 0.0255 - val_mean_squared_error: 0.0255
# Epoch 8/10
# 4/4 - 0s - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 9/10
# ...

# %%
cnn_predictions = model_cnn.predict(X_test)

cnn_score = r2_score(y_test,cnn_predictions)
print("R2 Score of CNN model = ",cnn_score)
# Out:
# R2 Score of CNN model =  0.37562922840576685

# %%
cnntrainScore = model_cnn.evaluate(X_train, y_train, verbose=0)
print('Train loss:', cnntrainScore[0]) 
print('Train accuracy:', cnntrainScore[1])
# Out:
# Train loss: 0.005242681596428156
# Train accuracy: 0.005242681596428156

# %%
cnnScore = model_cnn.evaluate(X_test, y_test, verbose=0)
print('Test loss:', cnnScore[0]) 
print('Test accuracy:', cnnScore[1])
# Out:
# Test loss: 0.0012775863287970424
# Test accuracy: 0.0012775863287970424

# %%
plot_predictions(y_test, cnn_predictions, "Predictions made by simple RNN model")

# %% [markdown]
# # New section - CNN-LSTM

# %%
from keras.models import Sequential
from keras.layers import Dense,RepeatVector
from keras.layers import Flatten
from keras.layers import TimeDistributed
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D

# %%
subsequences = 10
timesteps = X_train.shape[1]//subsequences
X_train_series_sub = X_train.reshape((X_train.shape[0], subsequences, timesteps, 1))
X_valid_series_sub = X_test.reshape((X_test.shape[0], subsequences, timesteps, 1))
print('Train set shape', X_train.shape)
print('Validation set shape', X_test.shape)
# Out:
# Train set shape (4000, 10, 1)
# Validation set shape (990, 10, 1)

# %%
X_train.shape[1]
# Out:
# 10

# %%
model_cnn_lstm1 = Sequential()
model_cnn_lstm1.add(TimeDistributed(Conv1D(filters=2, kernel_size=1, activation='relu'), input_shape=(X_train.shape[1],1)))
model_cnn_lstm1.add(TimeDistributed(MaxPooling1D(pool_size=10)))
model_cnn_lstm1.add(TimeDistributed(Flatten()))
# model_cnn_lstm1.add(LSTM(50, activation='relu'))
model_cnn_lstm1.add(Dense(1))
model_cnn_lstm1.compile(loss='mse', optimizer="adam")
model_cnn_lstm1 = model_cnn_lstm.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epoch, verbose=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-7e53ab0e7d50> in <module>()
#       1 model_cnn_lstm1 = Sequential()
# ----> 2 model_cnn_lstm1.add(TimeDistributed(Conv1D(filters=2, kernel_size=1, activation='relu'), input_shape=(X_train.shape[1],1)))
#       3 model_cnn_lstm1.add(TimeDistributed(MaxPooling1D(pool_size=10)))
#       4 model_cnn_lstm1.add(TimeDistributed(Flatten()))
#       5 # model_cnn_lstm1.add(LSTM(50, activation='relu'))
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     515     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     516     try:
# --> 517       result = method(self, *args, **kwargs)
#     518     finally:
#     519       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ...

# %%
model = Sequential()
model.add(Conv1D(filters=128, kernel_size=2, activation='relu', input_shape=(None, None, 10, 1)))
model.add(Conv1D(filters=128, kernel_size=2, activation='relu'))
model.add(Conv1D(filters=128, kernel_size=2, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# fit model
model.fit(X_train, Y_train, epochs=epoch, verbose=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-b5953b5df5d6> in <module>()
#       3 model.add(Conv1D(filters=128, kernel_size=2, activation='relu'))
#       4 model.add(Conv1D(filters=128, kernel_size=2, activation='relu'))
# ----> 5 model.add(MaxPooling1D(pool_size=1))
#       6 model.add(Flatten())
#       7 model.add(Dense(100, activation='relu'))
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     515     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     516     try:
# --> 517       result = method(self, *args, **kwargs)
#     518     finally:
#     519       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py in add(self, layer)
# ...
